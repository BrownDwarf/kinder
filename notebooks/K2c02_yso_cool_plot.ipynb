# %% [markdown]
# Make some more cool plots of the YSO sample.
# gully

# %% [markdown]
# # Make cool plots

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Read in the K2c02 data crossmatched with kplr

# %%
k2c2_yso_all_info = pd.read_csv('../analysis/K2C02_YSO_kplr_match.csv')

# %%
k2c2_yso_all_info.shape
# Out:
# (1658, 29)

# %%
k2c2_yso_all_info.columns
# Out:
# Index(['EPIC_ID', 'count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max',
#        'logstd', 'logiqr', 'fname', 'input_id', 'id', 'k2_ra', 'k2_dec',
#        'twomass', 'ucac', 'tyc', 'hip', 'kp', 'bmag', 'vmag', 'rmag', 'imag',
#        'jmag', 'hmag', 'kmag', 'kepflag'],
#       dtype='object')

# %%
k2c2_yso_all_info
# Out:
#         EPIC_ID  count      mean        std         min       25%       50%  \
# 632   203902450   3323  1.159171  10.503777 -493.530789  0.490673  1.054055
# 716   203928175   3249  1.168715   0.763535   -0.497281  0.542668  0.996219
# 152   203338523   3372  1.313698   0.445827    0.720946  0.909830  0.982975
# 583   203878861   3295  0.954711   3.068854  -44.926770  0.525368  0.940134
# 1529  205158239   3233  1.169200   0.536410    0.237024  0.736500  1.131303
# 641   203905576   3246  1.248756   0.683042   -2.111860  0.791807  1.096193
# 576   203874287   3346  1.383780   1.505391  -10.157756  0.914404  1.155316
# 242   203559274   3295  0.786364   1.746732  -90.832553  0.451221  0.873467
# 26    202687442   3331  1.205745   0.349531    0.803569  0.889353  0.919170
# 870   204141928   3333  0.762643   6.660416 -190.866206  0.445095  0.961853
# 638   203904426   3299  1.124303  13.049145 -739.952956  0.954330  1.102926
# ...

# %% [markdown]
# ## Previous version

# %%
tp = sns.jointplot(x="logiqr", y="logstd", alpha=0.2, kind='scatter',data=k2c2_yso_all_info, xlim=(-4, 2));
# Out:
# //anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ## New version

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)

# %%
sns.set_context('paper', font_scale=1.5)
sns.set_style('ticks')

# %%
0.71/1.41
# Out:
# 0.5035460992907801

# %%
plt.figure(figsize=[10, 8])
sc = plt.scatter(k2c2_yso_all_info['logiqr'], k2c2_yso_all_info['logstd'], c=k2c2_yso_all_info['kp'],
                 vmin=6, vmax=18, s=35, cmap=cmap, alpha=0.5)
plt.colorbar(sc, label='Kepler mag')
plt.xlabel('$\log{Q_{3}-Q_{1}}$')
plt.ylabel('$\log{\sigma}$')
plt.title('K2 Cycle 02 YSO candidates')
plt.xlim(-4, 0.1)
plt.ylim(-4, 2)

math_x = np.linspace(-4, 0.5, num=50)
math_y = math_x + np.log10(0.5035)
plt.plot(math_x, math_y, 'k--')
plt.scatter([-0.489], [-0.787], s=300, marker='*', c='r')
# Out:
# //anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
gi = k2c2_yso_all_info['kp'] < 9.0

df = k2c2_yso_all_info
sns.kdeplot(df.logiqr, df.logstd, shade=True)

sc = plt.scatter(k2c2_yso_all_info['logiqr'][gi], k2c2_yso_all_info['logstd'][gi], c=k2c2_yso_all_info['kp'][gi],
                 vmin=6, vmax=18, s=35, cmap=cmap, alpha=0.5)
plt.colorbar(sc, label='Kepler mag')
plt.xlabel('$\log{Q_{3}-Q_{1}}$')
plt.ylabel('$\log{\sigma}$')
plt.title('K2 Cycle 02 YSO candidates, Kp < 9.0')
plt.xlim(-4, 0.1)
plt.ylim(-4, 2)
# Out:
# (-4, 2)
# //anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
gi = (k2c2_yso_all_info['kp'] > 9.0) & (k2c2_yso_all_info['kp'] < 12.0)

df = k2c2_yso_all_info
sns.kdeplot(df.logiqr, df.logstd, shade=True)

sc = plt.scatter(k2c2_yso_all_info['logiqr'][gi], k2c2_yso_all_info['logstd'][gi], c=k2c2_yso_all_info['kp'][gi],
                 vmin=6, vmax=18, s=35, cmap=cmap, alpha=0.5)
plt.colorbar(sc, label='Kepler mag')
plt.xlabel('$\log{Q_{3}-Q_{1}}$')
plt.ylabel('$\log{\sigma}$')
plt.title('K2 Cycle 02 YSO candidates, 9.0 < Kp < 12.0')
plt.xlim(-4, 0.1)
plt.ylim(-4, 2)
# Out:
# (-4, 2)
# //anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
gi = (k2c2_yso_all_info['kp'] > 12.0) & (k2c2_yso_all_info['kp'] < 15.0)

df = k2c2_yso_all_info
sns.kdeplot(df.logiqr, df.logstd, shade=True)

sc = plt.scatter(k2c2_yso_all_info['logiqr'][gi], k2c2_yso_all_info['logstd'][gi], c=k2c2_yso_all_info['kp'][gi],
                 vmin=6, vmax=18, s=35, cmap=cmap, alpha=0.5)
plt.colorbar(sc, label='Kepler mag')
plt.xlabel('$\log{Q_{3}-Q_{1}}$')
plt.ylabel('$\log{\sigma}$')
plt.title('K2 Cycle 02 YSO candidates, 12.0 < Kp < 15.0')
plt.xlim(-4, 0.1)
plt.ylim(-4, 2)
# Out:
# (-4, 2)
# //anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
gi = (k2c2_yso_all_info['kp'] > 15.0)

df = k2c2_yso_all_info
sns.kdeplot(df.logiqr, df.logstd, shade=True)

sc = plt.scatter(k2c2_yso_all_info['logiqr'][gi], k2c2_yso_all_info['logstd'][gi], c=k2c2_yso_all_info['kp'][gi],
                 vmin=6, vmax=18, s=35, cmap=cmap, alpha=0.5)
plt.colorbar(sc, label='Kepler mag')
plt.xlabel('$\log{Q_{3}-Q_{1}}$')
plt.ylabel('$\log{\sigma}$')
plt.title('K2 Cycle 02 YSO candidates, 15.0 < Kp')
plt.xlim(-4, 0.1)
plt.ylim(-4, 2)
# Out:
# (-4, 2)
# //anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
gi = (k2c2_yso_all_info['kp'] == k2c2_yso_all_info['kp'])
plt.plot(k2c2_yso_all_info['kp'][gi],  k2c2_yso_all_info['logiqr'][gi], '.')

# %%
10**-0.8
# Out:
# 0.15848931924611134

# %% [markdown]
# ## Candidate selection

# %% [markdown]
# Main goals:
# 1. Observable
# 2. Has sunspots
# 3. No disk
#
# Selection criteria:
# 1. H < 10.5
# 2. K < 10.5
# 3. Above average level of activity
# 4. Periodic variability (i.e., not purely stochastic)
# 5. M or K spectral type
# 6. Oph or Upper sco.
# 7. Previously identified as T-Tauri star

# %%
gi = ((k2c2_yso_all_info['logiqr'] > -0.8) &
      (k2c2_yso_all_info['logiqr'] < -0.3) &
      (k2c2_yso_all_info['logstd'] < -0.6))

df = k2c2_yso_all_info
sns.kdeplot(df.logiqr, df.logstd, shade=True)

sc = plt.scatter(k2c2_yso_all_info['logiqr'][gi], k2c2_yso_all_info['logstd'][gi], c=k2c2_yso_all_info['kp'][gi],
                 vmin=6, vmax=18, s=35, cmap=cmap, alpha=0.5)
plt.colorbar(sc, label='Kepler mag')
plt.xlabel('$\log{Q_{3}-Q_{1}}$')
plt.ylabel('$\log{\sigma}$')
plt.title('K2 Cycle 02 YSO candidates')
plt.xlim(-1.5, 0)
plt.ylim(-1.3, -0.5)

math_x = np.linspace(-4, 0.5, num=50)
math_y = math_x + np.log10(0.5035)
plt.plot(math_x, math_y, 'k--')
plt.scatter([-0.489], [-0.787], s=300, marker='*', c='k')
# Out:
# //anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
plt.hist(k2c2_yso_all_info['kp'])
# Out:
# (array([   9.,   23.,   66.,   78.,  137.,  347.,  635.,  297.,   44.,   22.]),
#  array([  5.578 ,   6.8833,   8.1886,   9.4939,  10.7992,  12.1045,
#          13.4098,  14.7151,  16.0204,  17.3257,  18.631 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Plot an example

# %%
k2c2_yso_all_info[gi & (k2c2_yso_all_info.logstd < -1.40)]
# Out:
#        EPIC_ID  count      mean       std       min       25%       50%  \
# 422  203802422   3273  0.975449  0.039792  0.911211  0.931229  0.984145
# 424  203803109   3263  0.973511  0.039502  0.910391  0.929678  0.984408
# 738  203938834   3259  0.972514  0.039235  0.911414  0.930175  0.974531
#
#           75%       max    logstd   ...     hip      kp  bmag  vmag  rmag  \
# 422  1.010723  1.050145 -1.400204   ...     NaN  14.598   NaN   NaN   NaN
# 424  1.009672  1.298290 -1.403386   ...     NaN  13.441   NaN   NaN   NaN
# 738  1.009978  1.228658 -1.406326   ...     NaN  13.909   NaN   NaN   NaN
#
#      imag    jmag    hmag    kmag  kepflag
# 422   NaN  13.272  12.160  11.784        J
# 424   NaN  12.000  10.833  10.368        J
# 738   NaN  12.543  11.100  10.487        J
#
# [3 rows x 29 columns]

# %%
ii = 738

plt.figure(figsize=(10, 4))
file = k2c2_yso_all_info.fname[ii]
raw_lc = pd.read_csv(file, index_col=False)

plt.plot(raw_lc['BJD - 2454833'], raw_lc[' Corrected Flux'])
plt.ylim(0.80, 1.20)
plt.title("EPIC {} K2 C02 Light Curve".format(k2c2_yso_all_info.EPIC_ID[ii]))
plt.xlabel('BJD - 2454833')
plt.ylabel('Flux');

# %% [markdown]
# # Bokeh

# %%
df = k2c2_yso_all_info

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#
# <script type="text/javascript">
#     /* BEGIN //anaconda/lib/python3.4/site-packages/bokeh/server/static/js/bokeh.min.js */
# ...

# %%
from bokeh.plotting import figure, show, output_file, vplot

p1 = figure()
p1.plot_width=900
p1.title = "K2 Cycle 2 Young Star Candidates"
p1.grid.grid_line_alpha=0.3
p1.xaxis.axis_label = 'BJD - 2454833'
p1.yaxis.axis_label = 'Corrected Flux'

p1.line(raw_lc['BJD - 2454833'], raw_lc[' Corrected Flux'], color='#EF0E03', legend='AAPL')

show(p1)  # open a browser
# Out:
# <script type="text/javascript">
#         Bokeh.$(function() {
# ...
